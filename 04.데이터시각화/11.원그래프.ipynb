# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
plt.rc('axes', unicode_minus=False)

import pandas as pd
df = pd.read_csv('data/score.csv')

# %%
group = df.groupby('SW특기').size()
group
# Out:
# SW특기
# C#            2
# Java          3
# Javascript    1
# Python        2
# dtype: int64

# %%
labels = group.index
values = group.values
labels, values
# Out:
# (Index(['C#', 'Java', 'Javascript', 'Python'], dtype='object', name='SW특기'),
#  array([2, 3, 1, 2]))

# %% [markdown]
# 원그래프

# %% [markdown]
# SW특기

# %%
plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=True)  #counterclock=True: 시계반대방향?
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']

# %%
#2%이하일때 숫자 표시 안하는거
def custom_autopct(pct):
    if pct <= 2:
        return ''
    else:
        return f'{pct:.0f}%'

# %%
colors = ['#FFADAD','#FFD6A5','#FDFFB6','#CAFFBF','#9BF6FF','#A0C4FF']
plt.pie(values, labels=labels, explode=[0.03] * len(values), colors=colors,
        wedgeprops={'width':0.8, 'edgecolor':'white', 'linewidth':3},
        autopct=custom_autopct, startangle=90, counterclock=False)

plt.legend(loc=(1.1,0.3))

plt.show()
