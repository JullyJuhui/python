# %% [markdown]
# 데이터 전처리~~~~~~~~~

# %%
#Feature Engineering

# %%
import pandas as pd
train = pd.read_csv('data/타이타닉/train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#각 col간의 상관관계
before_corr = train.corr(numeric_only=True)
before_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test = pd.read_csv('data/타이타닉/test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data_list = [train, test]

# %%
data_list[1].head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train['Sex'].head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
#1. 성별을 코드로 변환한다.
for data in data_list:
    data['Sex'] = data['Sex'].astype('category').cat.codes

# %%
train['Sex'].head(), test['Sex'].head() #여자:0, 남자:1
# Out:
# (0    1
#  1    0
#  2    0
#  3    0
#  4    1
#  Name: Sex, dtype: int8,
#  0    1
#  1    0
#  2    1
#  3    1
#  4    0
#  Name: Sex, dtype: int8)

# %%
train['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
#성별별 평균나이 구해서 null값 채우기
gender_mean = train.groupby('Sex')['Age'].mean()
gender_mean
# Out:
# Sex
# 0    27.915709
# 1    30.726645
# Name: Age, dtype: float64

# %%
#나이가 null이면 성별 평균나이로 변환
for data in data_list:
    filt = (data['Sex']==0) & (data['Age'].isnull())
    data.loc[filt, 'Age']=gender_mean[0]

    filt = (data['Sex']==1) & (data['Age'].isnull())
    data.loc[filt, 'Age']=gender_mean[1]

# %%
train['AgeRange'] = pd.cut(train['Age'], 5)  #train 나이를 5개 그룹으로 나눔
train['AgeRange'].value_counts()
# Out:
# AgeRange
# (16.336, 32.252]    523
# (32.252, 48.168]    188
# (0.34, 16.336]      100
# (48.168, 64.084]     69
# (64.084, 80.0]       11
# Name: count, dtype: int64

# %%
for data in data_list:
    filt = data['Age'] <= 16
    data.loc[filt, 'Age2'] = 0
    
    filt = (data['Age'] > 16) & (data['Age'] <= 32)
    data.loc[filt, 'Age2'] = 1

    filt = (data['Age'] > 32) & (data['Age'] <= 48)
    data.loc[filt, 'Age2'] = 2

    filt = (data['Age'] > 48) & (data['Age'] <= 64)
    data.loc[filt, 'Age2'] = 3

    filt = data['Age'] > 64
    data.loc[filt, 'Age2'] = 4

# %%
train['Age2'].value_counts()
# Out:
# Age2
# 1.0    523
# 2.0    188
# 0.0    100
# 3.0     69
# 4.0     11
# Name: count, dtype: int64

# %%
if 'AgeRange' in train.columns:
    train.drop(columns='AgeRange', inplace=True)

# %%
if 'AgeRange' in test.columns:
    test.drop(columns='AgeRange', inplace=True)

# %%
train.columns, test.columns
# Out:
# (Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age2'],
#        dtype='object'),
#  Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#         'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age2'],
#        dtype='object'))

# %%
for data in data_list:
    if 'Age2' in data.columns:
        data['Age'] = data['Age2']
        data.drop(columns='Age2', inplace=True)

# %%
train['Age'].value_counts()
# Out:
# Age
# 1.0    523
# 2.0    188
# 0.0    100
# 3.0     69
# 4.0     11
# Name: count, dtype: int64

# %%
train['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#4. 이름에서 호칭을 뽑아서 코드로 변환
train['Title'] = train['Name'].str.extract(' ([A-Za-z]+)\\.')
titles = train['Title'].value_counts()
titles.index
# Out:
# Index(['Mr', 'Miss', 'Mrs', 'Master', 'Dr', 'Rev', 'Col', 'Mlle', 'Major',
#        'Ms', 'Mme', 'Don', 'Lady', 'Sir', 'Capt', 'Countess', 'Jonkheer'],
#       dtype='object', name='Title')

# %%
others = [i for i in titles.index if i not in ['Mr', 'Miss', 'Mrs', 'Master']]

# %%
print(others)
# Out:
# ['Dr', 'Rev', 'Col', 'Mlle', 'Major', 'Ms', 'Mme', 'Don', 'Lady', 'Sir', 'Capt', 'Countess', 'Jonkheer']

# %%
train['Title'] = train['Title'].replace(others, 'Other')  #others배열에 속해있으면 Other로 바꿈
train['Title'].value_counts()
# Out:
# Title
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Other      27
# Name: count, dtype: int64

# %%
train['Title_name'] = train['Title'].astype('category').cat.codes
train[['Title', 'Title_name']].value_counts()
# Out:
# Title   Title_name
# Mr      2             517
# Miss    1             182
# Mrs     3             125
# Master  0              40
# Other   4              27
# Name: count, dtype: int64

# %%
for data in data_list:
    data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\\.')
    titles = data['Title'].value_counts()

    others = [i for i in titles.index if i not in ['Mr', 'Miss', 'Mrs', 'Master']]
    data['Title'] = data['Title'].replace(others, 'Other')
    
    data['Title_name'] = data['Title'].astype('category').cat.codes

# %%
test[['Title', 'Title_name']].value_counts()
# Out:
# Title   Title_name
# Mr      2             240
# Miss    1              78
# Mrs     3              72
# Master  0              21
# Other   4               7
# Name: count, dtype: int64

# %%
#Name, Title col 지우기
for data in data_list:
    if 'Name' in data.columns:
        data.drop(columns='Name', inplace=True)
    
    if 'Title' in data.columns:
        data.drop(columns='Title', inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  1.0      1      0         A/5 21171
# 1            2         1       1    0  2.0      1      0          PC 17599
# 2            3         1       3    0  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  2.0      1      0            113803
# 4            5         0       3    1  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title_name
# 0   7.2500   NaN        S           2
# 1  71.2833   C85        C           3
# 2   7.9250   NaN        S           1
# 3  53.1000  C123        S           3
# 4   8.0500   NaN        S           2

# %%
#5. family size 구하기 (SibSp + Parch + 1)

# %%
for data in data_list:
    data['FamilySize'] = data['SibSp'] + data['Parch'] + 1

# %%
train['FamilySize'].value_counts()
# Out:
# FamilySize
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %%
for data in data_list:
    if 'SibSp' in data.columns:
        data.drop(columns='SibSp', inplace=True)

    if 'Parch' in data.columns:
        data.drop(columns='Parch', inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title_name       0
# FamilySize       0
# dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
for data in data_list:
    data.fillna({'Embarked':'S'}, inplace=True)

# %%
#6. 항구이름을 코드로 변환
for data in data_list:
    for idx in range(len(data)):
        if data.loc[idx, 'Embarked']=='S':
            data.loc[idx, 'Embarked']=0

        elif data.loc[idx, 'Embarked']=='C':
            data.loc[idx, 'Embarked']=1

        elif data.loc[idx, 'Embarked']=='Q':
            data.loc[idx, 'Embarked']=2

    data['Embarked'] = data['Embarked'].apply(lambda x :int(x) if not isinstance(x, int) else x)

# %%
train['Embarked'].value_counts()
# Out:
# Embarked
# 0    646
# 1    168
# 2     77
# Name: count, dtype: int64

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'Ticket', 'Fare',
#        'Cabin', 'Embarked', 'Title_name', 'FamilySize'],
#       dtype='object')

# %%
train['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
#7. Cabin을 앞자리 1자리 코드로 변환
for data in data_list:
    # data['Cabin'] = data['Cabin'].fillna('N')
    data.fillna({'Cabin': 'N'}, inplace=True)
    data['Cabin'] = data['Cabin'].apply(lambda x:x[0])
    data['Cabin'] = data['Cabin'].astype('category').cat.codes  #카테고리.코드값

# %%
train['Cabin'].value_counts()
# Out:
# Cabin
# 7    687
# 2     59
# 1     47
# 3     33
# 4     32
# 0     15
# 5     13
# 6      4
# 8      1
# Name: count, dtype: int64

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket     Fare  Cabin  \
# 0            1         0       3    1  1.0         A/5 21171   7.2500      7
# 1            2         1       1    0  2.0          PC 17599  71.2833      2
# 2            3         1       3    0  1.0  STON/O2. 3101282   7.9250      7
# 3            4         1       1    0  2.0            113803  53.1000      2
# 4            5         0       3    1  2.0            373450   8.0500      7
#
#    Embarked  Title_name  FamilySize
# 0         0           2           2
# 1         1           3           2
# 2         0           1           1
# 3         0           3           2
# 4         0           2           1

# %%
#8. Fare(요금)dmf 4개의 그룹으로 나누기
train['FareRange'] = pd.cut(train['Fare'], 4)
train['FareRange'].value_counts()
# Out:
# FareRange
# (-0.512, 128.082]     853
# (128.082, 256.165]     29
# (256.165, 384.247]      6
# (384.247, 512.329]      3
# Name: count, dtype: int64

# %%
for data in data_list:
    filt = data['Fare']<=128
    data.loc[filt, 'Fare2']=0

    filt = (data['Fare']>128) & (data['Fare']<=256)
    data.loc[filt, 'Fare2']=1

    filt = (data['Fare']>256) & (data['Fare']<=384)
    data.loc[filt, 'Fare2']=2
    
    filt = (data['Fare']>384)
    data.loc[filt, 'Fare2']=3

    data.fillna({'Fare2':0}, inplace=True)

# %%
train['Fare2'].value_counts()
# Out:
# Fare2
# 0.0    853
# 1.0     29
# 2.0      6
# 3.0      3
# Name: count, dtype: int64

# %%
for data in data_list:
    if 'Fare2' in data.columns:
        data['Fare'] = data['Fare2']
        data.drop(columns='Fare2', inplace=True)

    if 'FareRange' in data.columns:
        data.drop(columns='FareRange', inplace=True)

# %%
train.columns, test.columns
# Out:
# (Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'Ticket', 'Fare',
#         'Cabin', 'Embarked', 'Title_name', 'FamilySize'],
#        dtype='object'),
#  Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'Ticket', 'Fare', 'Cabin',
#         'Embarked', 'Title_name', 'FamilySize'],
#        dtype='object'))

# %%
#9. 필요없는 col 제거: 'PassengerId', 'Ticket', 'Cabin' 삭제
drop_list = ['PassengerId', 'Ticket', 'Cabin']
for data in data_list:
    for col in drop_list:
        if col in data.columns:
            data.drop(columns=col, inplace=True)

# %% [markdown]
# 데이터 전처리 완료! - Feature Engineering

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0         0       3    1  1.0   0.0         0           2           2
# 1         1       1    0  2.0   0.0         1           3           2
# 2         1       3    0  1.0   0.0         0           1           1
# 3         1       1    0  2.0   0.0         0           3           2
# 4         0       3    1  2.0   0.0         0           2           1

# %%
test.head()
# Out:
#    Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0       3    1  2.0   0.0         2           2           1
# 1       3    0  2.0   0.0         0           3           2
# 2       2    1  3.0   0.0         2           2           1
# 3       3    1  1.0   0.0         0           2           1
# 4       3    0  1.0   0.0         0           3           3

# %%
train.to_csv('data/타이타닉/훈련.csv', index=False)
test.to_csv('data/타이타닉/테스트.csv', index=False)

# %%
before_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
train.corr(numeric_only=True)
# Out:
#             Survived    Pclass       Sex       Age      Fare  Embarked  \
# Survived    1.000000 -0.338481 -0.543351 -0.043800  0.147466  0.106811
# Pclass     -0.338481  1.000000  0.131900 -0.358769 -0.298580  0.045702
# Sex        -0.543351  0.131900  1.000000  0.070220 -0.114771 -0.116569
# Age        -0.043800 -0.358769  0.070220  1.000000  0.063220 -0.051334
# Fare        0.147466 -0.298580 -0.114771  0.063220  1.000000  0.047596
# Embarked    0.106811  0.045702 -0.116569 -0.051334  0.047596  1.000000
# Title_name -0.052471 -0.195910  0.040484  0.427999 -0.044644 -0.081928
# FamilySize  0.016639  0.065997 -0.200988 -0.217063  0.098769 -0.080281
#
#             Title_name  FamilySize
# Survived     -0.052471    0.016639
# Pclass       -0.195910    0.065997
# Sex           0.040484   -0.200988
# Age           0.427999   -0.217063
# Fare         -0.044644    0.098769
# Embarked     -0.081928   -0.080281
# Title_name    1.000000   -0.207530
# FamilySize   -0.207530    1.000000

# %%
train = pd.read_csv('data/타이타닉/훈련.csv')
train.corr(numeric_only=True)
# Out:
#             Survived    Pclass       Sex       Age      Fare  Embarked  \
# Survived    1.000000 -0.338481 -0.543351 -0.043800  0.147466  0.106811
# Pclass     -0.338481  1.000000  0.131900 -0.358769 -0.298580  0.045702
# Sex        -0.543351  0.131900  1.000000  0.070220 -0.114771 -0.116569
# Age        -0.043800 -0.358769  0.070220  1.000000  0.063220 -0.051334
# Fare        0.147466 -0.298580 -0.114771  0.063220  1.000000  0.047596
# Embarked    0.106811  0.045702 -0.116569 -0.051334  0.047596  1.000000
# Title_name -0.052471 -0.195910  0.040484  0.427999 -0.044644 -0.081928
# FamilySize  0.016639  0.065997 -0.200988 -0.217063  0.098769 -0.080281
#
#             Title_name  FamilySize
# Survived     -0.052471    0.016639
# Pclass       -0.195910    0.065997
# Sex           0.040484   -0.200988
# Age           0.427999   -0.217063
# Fare         -0.044644    0.098769
# Embarked     -0.081928   -0.080281
# Title_name    1.000000   -0.207530
# FamilySize   -0.207530    1.000000

# %%
train
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0           0       3    1  1.0   0.0         0           2           2
# 1           1       1    0  2.0   0.0         1           3           2
# 2           1       3    0  1.0   0.0         0           1           1
# 3           1       1    0  2.0   0.0         0           3           2
# 4           0       3    1  2.0   0.0         0           2           1
# ..        ...     ...  ...  ...   ...       ...         ...         ...
# 886         0       2    1  1.0   0.0         0           4           1
# 887         1       1    0  1.0   0.0         0           1           1
# 888         0       3    0  1.0   0.0         0           1           4
# 889         1       1    1  1.0   0.0         1           2           1
# 890         0       3    1  1.0   0.0         2           2           1
#
# [891 rows x 8 columns]

# %%
train.head(1)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0         0       3    1  1.0   0.0         0           2           2

# %%
X_train = train.iloc[:, 1:]
y_train = train.iloc[:, 0]

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
train.head(1)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0         0       3    1  1.0   0.0         0           2           2

# %%
X_train = train.iloc[:, 1:]
y_train_pred = model.predict(X_train)
y_train_pred.shape
# Out:
# (891,)

# %%
train['Prediction']=y_train_pred
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize  \
# 0         0       3    1  1.0   0.0         0           2           2
# 1         1       1    0  2.0   0.0         1           3           2
# 2         1       3    0  1.0   0.0         0           1           1
# 3         1       1    0  2.0   0.0         0           3           2
# 4         0       3    1  2.0   0.0         0           2           1
#
#    Prediction
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0

# %%
filt = train['Survived']==train['Prediction']
right = train[filt]
train.shape, right.shape, model.score(X_train, y_train), right.shape[0]/train.shape[0]
# Out:
# ((891, 9), (748, 9), 0.8395061728395061, 0.8395061728395061)

# %%
test.head(1)
# Out:
#    Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0       3    1  2.0   0.0         2           2           1

# %%
X_test = test.iloc[:, :]
y_test_pred = model.predict(X_test)

# %%
test['Prediction'] = y_test_pred

# %%
test.head()
# Out:
#    Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize  Prediction
# 0       3    1  2.0   0.0         2           2           1           0
# 1       3    0  2.0   0.0         0           3           2           1
# 2       2    1  3.0   0.0         2           2           1           0
# 3       3    1  1.0   0.0         0           2           1           0
# 4       3    0  1.0   0.0         0           3           3           1

# %%
df_test = pd.read_csv('data/타이타닉/test.csv')
df_test['Prediction'] = y_test_pred
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Prediction
# 0  34.5      0      0   330911   7.8292   NaN        Q           0
# 1  47.0      1      0   363272   7.0000   NaN        S           1
# 2  62.0      0      0   240276   9.6875   NaN        Q           0
# 3  27.0      0      0   315154   8.6625   NaN        S           0
# 4  22.0      1      1  3101298  12.2875   NaN        S           1

# %%
submission = pd.read_csv('data/타이타닉/gender_submission.csv')
submission['Prediction'] = y_test_pred
submission.to_csv('data/타이타닉/gender_submission.csv', index=False)

# %%
train = pd.read_csv('data/타이타닉/훈련.csv')
train['Age'].value_counts()
# Out:
# Age
# 1.0    523
# 2.0    188
# 0.0    100
# 3.0     69
# 4.0     11
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 3))
sns.countplot(x='Age', hue='Survived', data=train, palette='Set2')
plt.show()

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title_name  FamilySize
# 0         0       3    1  1.0   0.0         0           2           2
# 1         1       1    0  2.0   0.0         1           3           2
# 2         1       3    0  1.0   0.0         0           1           1
# 3         1       1    0  2.0   0.0         0           3           2
# 4         0       3    1  2.0   0.0         0           2           1

# %%
def rate(col):
    group = train[col].value_counts()  #train.groupby('Age').size()
    df_total = group.to_frame('전체')

    group = train[train['Survived']==1][col].value_counts()
    df_survived = group.to_frame('생존')

    join = df_total.join(df_survived)
    join['사망'] = join['전체']-join['생존']
    join['생존율'] = join['생존']/join['전체']

    return join

# %%
df = rate('Age')
df_train = pd.read_csv('data/타이타닉/train.csv')
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train['AgeRange'] = pd.cut(df_train['Age'], 5)
range = df_train['AgeRange'].value_counts()
range = pd.Series(range)
ranges = range.sort_index().index
index = []
for range in ranges:
    range = str(range).replace('(', '').replace(']', '').split(',')
    range = f'{float(range[0]):.0f}~{float(range[1]):.0f}'
    index.append(range)

index
# Out:
# ['0~16', '16~32', '32~48', '48~64', '64~80']

# %%
df = rate('Age')
df = df.sort_index()
df.index=index
df
# Out:
#         전체   생존   사망       생존율
# 0~16   100   55   45  0.550000
# 16~32  523  180  343  0.344168
# 32~48  188   76  112  0.404255
# 48~64   69   30   39  0.434783
# 64~80   11    1   10  0.090909

# %%
xticks = df.index*4
plt.bar(xticks-0.5, df['생존'], width=1)
plt.bar(xticks+0.5, df['사망'], width=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[243], line 2
#       1 xticks = df.index*4
# ----> 2 plt.bar(xticks-0.5, df['생존'], width=1)
#       3 plt.bar(xticks+0.5, df['사망'], width=1)
#       4 plt.show()
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:7304, in Index._arith_method(self, other, op)
#    7294 if (
#    7295     isinstance(other, Index)
#    7296     and is_object_dtype(other.dtype)
#    (...)
#    7300     # a chance to implement ops before we unwrap them.
#    7301     # See https://github.com/pandas-dev/pandas/issues/31109
#    7302     return NotImplemented
# -> 7304 return super()._arith_method(other, op)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:1391, in IndexOpsMixin._arith_method(self, other, op)
#    1388     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1390 with np.errstate(all="ignore"):
# -> 1391     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1393 return self._construct_result(result, name=res_name)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
