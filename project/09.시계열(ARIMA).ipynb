# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
df_stock = fdr.StockListing('KRX') #한국증시 #뉴욕증시:NYSE
filt1 = df_stock['Market']=='KOSPI'
df_stock = df_stock[filt1]
df = df_stock[['Name', 'Code', 'Close', 'Changes', 'ChagesRatio', 'High', 'Low', 'Volume', 'Marcap']]
df.columns = ['종목명', '종목코드', '종가', '등락폭', '등락률', '고가', '저가', '거래량', '시가총액']

# %%
df['등락률'] = [f'{n}%' for n in df['등락률']]
df
# Out:
#            종목명    종목코드       종가    등락폭      등락률       고가       저가       거래량  \
# 0         삼성전자  005930    94400   5400    6.07%    94500    92700  35269748
# 1       SK하이닉스  000660   428000  32500    8.22%   439250   416500   6835852
# 2     LG에너지솔루션  373220   359500 -39500    -9.9%   367500   352500    541859
# 3     삼성바이오로직스  207940  1014000   5000     0.5%  1022000  1009000     73825
# 4        삼성전자우  005935    74400   4400    6.29%    74900    73500   7330096
# ...        ...     ...      ...    ...      ...      ...      ...       ...
# 2874    씨앤에스링크  245450     1300   -180  -12.16%     1470     1300         2
# 2875      씨알푸드  236030      999     99    11.0%      999      900      1900
# 2876     나라소프트  288490      105      0     0.0%        0        0         0
# 2877       테크엔  308700      199      0     0.0%        0        0         0
# 2878       썬테크  217320      700      0     0.0%        0        0         0
#
#                  시가총액
# 0     558813819836800
# 1     311585012220000
# 2      84123000000000
# 3      72170436000000
# 4      60708515001600
# ...               ...
# 2874       2053948000
# 2875       2031298668
# 2876       1834515585
# 2877       1472600000
# 2878        735000000
#
# [2879 rows x 9 columns]

# %%
df_stock.head()
# Out:
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         94400          1     5400
# 1  000660  KR7000660001    SK하이닉스  KOSPI        428000          1    32500
# 2  373220  KR7373220003  LG에너지솔루션  KOSPI        359500          2   -39500
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       1014000          1     5000
# 4  005935  KR7005931001     삼성전자우  KOSPI         74400          1     4400
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0         6.07    94000    94500    92700  35269748  3311084659050
# 1         8.22   426000   439250   416500   6835852  2911518119518
# 2        -9.90   367500   367500   352500    541859   194275452500
# 3         0.50  1016000  1022000  1009000     73825    74881272500
# 4         6.29    74200    74900    73500   7328454   543098511075
#
#             Marcap      Stocks MarketId
# 0  558813819836800  5919637922      STK
# 1  311585012220000   728002365      STK
# 2   84123000000000   234000000      STK
# 3   72170436000000    71174000      STK
# 4   60708515001600   815974664      STK

# %%
filt = df_stock['Name'].str.contains('삼성전자')
df_stock[filt]
# Out:
#      Code        ISU_CD   Name Market Dept  Close ChangeCode  Changes  \
# 0  005930  KR7005930003   삼성전자  KOSPI       94400          1     5400
# 4  005935  KR7005931001  삼성전자우  KOSPI       74400          1     4400
#
#    ChagesRatio   Open   High    Low    Volume         Amount           Marcap  \
# 0         6.07  94000  94500  92700  35269748  3311084659050  558813819836800
# 4         6.29  74200  74900  73500   7312866   541939215575   60708515001600
#
#        Stocks MarketId
# 0  5919637922      STK
# 4   815974664      STK

# %%
code = '005930'
df = fdr.DataReader(code, '2024-01-01')
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2024-01-02  78200  79800  78200  79600  17142847  0.014013
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305

# %%
df.index[0]
# Out:
# Timestamp('2024-01-02 00:00:00')

# %%
plt.figure(figsize=(10,3))
plt.plot(df.index, df['Close'])
plt.show()

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2024-01-02  78200  79800  78200  79600  17142847  0.014013
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305

# %%
df['년'] = df.index.year
df['월'] = df.index.month
df['일'] = df.index.day
df
# Out:
#              Open   High    Low  Close    Volume    Change     년   월   일
# Date
# 2024-01-02  78200  79800  78200  79600  17142847  0.014013  2024   1   2
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663  2024   1   3
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195  2024   1   4
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000  2024   1   5
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305  2024   1   8
# ...           ...    ...    ...    ...       ...       ...   ...  ..  ..
# 2025-09-29  83300  85000  83200  84200  13069094  0.010804  2025   9  29
# 2025-09-30  84600  84900  83400  83900  16319061 -0.003563  2025   9  30
# 2025-10-01  84900  86200  84700  86000  22039361  0.025030  2025  10   1
# 2025-10-02  89300  90300  88700  89000  49883028  0.034884  2025  10   2
# 2025-10-10  94000  94500  92700  94400  34625685  0.060674  2025  10  10
#
# [430 rows x 9 columns]

# %%
df = df[df['년']==2024]
df.tail()
# Out:
#              Open   High    Low  Close    Volume    Change     년   월   일
# Date
# 2024-12-23  53400  54000  53300  53500  13672650  0.009434  2024  12  23
# 2024-12-24  53700  54500  53600  54400  11634677  0.016822  2024  12  24
# 2024-12-26  54500  54600  53500  53600  10517075 -0.014706  2024  12  26
# 2024-12-27  53500  54100  53200  53700  10747196  0.001866  2024  12  27
# 2024-12-30  53300  54000  53100  53200  12624702 -0.009311  2024  12  30

# %%
group = df.groupby('월')[['Close', 'Volume']].mean()
group['Vol'] = group['Volume']/1000
group
# Out:
#            Close        Volume           Vol
# 월
# 1   74454.545455  1.807449e+07  18074.489045
# 2   73684.210526  1.573450e+07  15734.499158
# 3   75760.000000  2.241809e+07  22418.086800
# 4   80595.238095  2.306391e+07  23063.906095
# 5   77780.000000  2.105444e+07  21054.439100
# 6   78831.578947  1.852085e+07  18520.854368
# 7   84382.608696  2.074605e+07  20746.049957
# 8   76500.000000  1.914334e+07  19143.341714
# 9   66033.333333  2.870442e+07  28704.417722
# 10  59295.000000  2.686515e+07  26865.149200
# 11  55776.190476  2.768583e+07  27685.829857
# 12  54035.000000  1.936910e+07  19369.097400

# %%
df = group.copy()

# %%
import numpy as np

plt.figure(figsize=(10, 3))
plt.plot(df.index, df['Close'], marker='*', color="orange", ms=16, mec='white', mew=1.2)
xticks = [x for x in df.index]
plt.xticks(xticks, [f'{x}월' for x in xticks])

ymin = int(int(df['Close'].min()-5000)/10000)*10000
ymax = int(df['Close'].max()+10000)
yticks = [y for y in range(ymin, ymax, 10000)]
plt.yticks(yticks, [f'{y:,}원' for y in yticks])

for idx, close in enumerate(df['Close']):
    plt.text(df.index[idx], close+2000, f'{close:.0f}', ha='center', size=8)

plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.bar(df.index, df['Volume'], color='skyblue')

xticks = [x for x in df.index]
plt.xticks(xticks, [f'{x}월' for x in xticks])

plt.show()

# %%
#시계열 ARIMA

# %%
code ='005930'
ss = fdr.DataReader(code, '2020-01-01', '2021-08-30')
ss.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-08-24  73900  75700  73900  75600  21016913  0.031378
# 2021-08-25  76200  76600  74900  75700  22319664  0.001323
# 2021-08-26  76100  76200  74600  74600  16671494 -0.014531
# 2021-08-27  74300  75000  73800  74300  15172748 -0.004021
# 2021-08-30  75400  75500  74200  74600  12686999  0.004038

# %%
n_train = int(len(ss) * 0.7)

len(ss), n_train
# Out:
# (413, 289)

# %%
y_train = ss['Close'][:n_train]
y_test = ss['Close'][n_train:]

# %%
len(y_train), len(y_test)
# Out:
# (289, 124)

# %%
y_train[:5], y_test[:5]
# Out:
# (Date
#  2020-01-02    55200
#  2020-01-03    55500
#  2020-01-06    55500
#  2020-01-07    55800
#  2020-01-08    56800
#  Name: Close, dtype: int64,
#  Date
#  2021-03-05    82100
#  2021-03-08    82000
#  2021-03-09    81400
#  2021-03-10    80900
#  2021-03-11    82000
#  Name: Close, dtype: int64)

# %%
plt.figure(figsize=(10,3))
y_train.plot()
y_test.plot()
plt.show()

# %%
from pmdarima.arima import ndiffs
ndif = ndiffs(y_train, alpha=0.05, test='adf', max_d=6)
ndif
# Out:
# 1

# %%
import pmdarima as pm
model = pm.auto_arima(
    y_train, d=1, start_p=0, max_p=3, start_q=0, max_q=3, m=1, seasonal=False, trace=True
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4934.821, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4936.780, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4936.799, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4934.428, Time=0.00 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4938.798, Time=0.05 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.102 seconds

# %%
model.fit(y_train)
# Out:
# ARIMA(order=(0, 1, 0), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
y_pred = model.predict(n_periods=len(y_test))
y_pred
# Out:
# C:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 289    82400.0
# 290    82400.0
# 291    82400.0
# 292    82400.0
# 293    82400.0
#         ...
# 408    82400.0
# 409    82400.0
# 410    82400.0
# 411    82400.0
# 412    82400.0
# Length: 124, dtype: float64

# %%
plt.figure(figsize=(10,3))
plt.plot(y_train,label='훈련')
plt.plot(y_test, label='테스트')
plt.plot(y_test.index, y_pred, label='예측')
plt.legend()
plt.show()

# %%
def one_step():
    pred, conf_int = model.predict(n_periods=1, return_conf_int=True)
    #print('예측:', pred.tolist()[0])
    #print('예측 하한, 상한:', conf_int[0])
    return pred.tolist()[0], conf_int[0]

# %%
y_pred=[]
y_lower=[]
y_upper=[]
for test in y_test:
    pred, conf = one_step()
    y_pred.append(pred)
    y_lower.append(conf[0])
    y_upper.append(conf[1])
    #print(pred)
    model.update(test)
# Out:
# C:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
len(y_pred), len(y_upper), len(y_lower)
y_pred[0], y_upper[0], y_lower[0]
# Out:
# (82400.0, 84878.71094930936, 79921.28905069064)

# %%
y_test.index
# Out:
# DatetimeIndex(['2021-03-05', '2021-03-08', '2021-03-09', '2021-03-10',
#                '2021-03-11', '2021-03-12', '2021-03-15', '2021-03-16',
#                '2021-03-17', '2021-03-18',
#                ...
#                '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20',
#                '2021-08-23', '2021-08-24', '2021-08-25', '2021-08-26',
#                '2021-08-27', '2021-08-30'],
#               dtype='datetime64[ns]', name='Date', length=124, freq=None)

# %%
import pandas as pd
pred = pd.Series(y_pred, index=y_test.index)
lower = pd.Series(y_lower, index=y_test.index)
upper = pd.Series(y_upper, index=y_test.index)

# %%
data = {'예측':y_pred, '하한':y_lower, '상한':y_upper}

# %%
df = pd.DataFrame(data,index=y_test.index)
df['실제'] = y_test
df
# Out:
#                  예측            하한            상한     실제
# Date
# 2021-03-05  82400.0  79921.289051  84878.710949  82100
# 2021-03-08  82100.0  79621.289051  84578.710949  82000
# 2021-03-09  82000.0  79521.289051  84478.710949  81400
# 2021-03-10  81400.0  78921.289051  83878.710949  80900
# 2021-03-11  80900.0  78421.289051  83378.710949  82000
# ...             ...           ...           ...    ...
# 2021-08-24  73300.0  71040.218891  75559.781109  75600
# 2021-08-25  75600.0  73340.218891  77859.781109  75700
# 2021-08-26  75700.0  73440.218891  77959.781109  74600
# 2021-08-27  74600.0  72340.218891  76859.781109  74300
# 2021-08-30  74300.0  72040.218891  76559.781109  74600
#
# [124 rows x 4 columns]

# %%
plt.figure(figsize=(10,3))
y_test.plot(label='테스트')
y_train.plot(label='훈련')
plt.fill_between(lower.index, lower, upper, color='r', alpha=0.3)
plt.grid(True, ls='--', lw=0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
y_test.plot(label='실제')
pred.plot(label='예측')
#y_train.plot(label='훈련')
plt.fill_between(lower.index, lower, upper, color='b', alpha=0.2)
plt.grid(True, ls='--', lw=0.5)
plt.legend()
plt.show()

# %%
x = [1,2,3,4]
y=[-10,5,-20,20]

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y)
plt.show()

# %%
#티커 종목코드 구하기
import FinanceDataReader as fdr
df = fdr.StockListing('KRX')
names = ['삼성전자','카카오','NAVER','LG전자','현대차']
filt = df['Name'].isin(names)
df = df[filt][['Code','Name']]
names = list(df['Name'])
codes = list(df['Code'])
names, codes
# Out:
# (['삼성전자', '현대차', 'NAVER', '카카오', 'LG전자'],
#  ['005930', '005380', '035420', '035720', '066570'])

# %%
def getData(code, start, end):
    df = fdr.DataReader(code, start, end)
    return df

# %%
#1)특정회사의 start ~end 까지 주식 데이터
code = codes[1]
start = '2025-01-01'
end = '2025-09-30'
df = getData(code, start, end)  #fdr.DataReader(code, start, end)
y = df['Close']

# %%
#2)모델생성 후 학습
import warnings
warnings.filterwarnings('ignore')

import pmdarima as pm
model = pm.auto_arima(
    y_train, d=1, start_p=0, max_p=3, start_q=0, max_q=3, m=1, seasonal=False, trace=True
)
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4934.821, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4936.780, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4936.799, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4934.428, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4938.798, Time=0.04 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.092 seconds
# ARIMA(order=(0, 1, 0), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
#3)예측함수
def one_step():
    pred, conf = model.predict(n_periods=1, return_conf_int=True)
    return pred.tolist()[0], conf[0]

# %%
#4)예측함수 실행
pred=[]
lower=[]
upper=[]
for y in y_train:
    y_pred, conf = one_step()
    pred.append(y_pred)
    lower.append(conf[0])
    upper.append(conf[1])
    model.update(y)

# %%
#pred[:5], upper[:5], lower[:5]

# %%
#5)결과를 데이터프레임으로 변환
import pandas as pd
df = pd.DataFrame(y_train)
df['예측'] = pred
df['하한'] = lower
df['상한'] = upper
df.head()
# Out:
#             Close       예측            하한            상한
# Date
# 2020-01-02  55200  82400.0  79921.289051  84878.710949
# 2020-01-03  55500  55200.0  51264.700851  59135.299149
# 2020-01-06  55500  55500.0  51511.022772  59488.977228
# 2020-01-07  55800  55500.0  51511.022772  59488.977228
# 2020-01-08  56800  55800.0  51811.022772  59788.977228

# %%
#6)그래프출력
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

plt.figure(figsize=(10, 3))
df['Close'].plot(label='실제')
df['예측'].plot(label='예측')
plt.fill_between(df.index, df['하한'], df['상한'], color='b', alpha=0.1)
plt.grid(True, ls='--', lw=0.5)
plt.title(f'삼성전자 {start}~{end} 주가예측', size=15)
plt.legend()
plt.show()

# %%
code = '005930'
start = '2024-01-01'
end = '2025-09-30'

df = fdr.DataReader(code, start, end)
df['year'] = df.index.year
df['month'] = df.index.month

group = df.groupby(['year', 'month'])[['Close', 'Volume']].mean()
group.reset_index(inplace=True)

plt.figure(figsize=(10,4))
plt.plot(group.index, group['Close'], marker='s', color='deeppink')

xticks = [x for x in group.index]
plt.xticks(xticks, [f"{group.loc[idx, 'year']}-{group.loc[idx, 'month']}" for idx in xticks], rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,4))
plt.bar(group.index, group['Volume'], color='orange')

xticks = [x for x in group.index]
plt.xticks(xticks, [f"{group.loc[idx, 'year']}-{group.loc[idx, 'month']}" for idx in xticks], rotation=45)

plt.show()
