# %%
import pandas as pd

# %%
df = pd.read_csv('data/score.csv')

# %%
df_info = df[['지원번호', '이름', '학교', '키', 'SW특기']]

df['평균'] = df.apply(lambda row: row['국어':'사회'].mean(), axis=1)
df_score = df[['지원번호', '이름', '국어', '영어', '수학', '과학', '사회', '평균']]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
df = pd.read_csv('data/score.csv')
df['평균'] = df['평균'] = df.apply(lambda row: row['국어':'사회'].mean(), axis=1)
plt.bar(df['이름'], df['평균'], color = 'skyblue', ec='deeppink', hatch='..')
plt.show()
